# %%
import matplotlib.pyplot as plt
import networkx as nx
import pandas as pd
import numpy as np

#green line
MyGraph = nx.Graph()
MyGraph.add_node('A', npos=(33, 0), ccn='#0000FF')
MyGraph.add_node('B', npos=(38, 25), ccn='#00FF00')
MyGraph.add_node('C', npos=(45.1, 25), ccn='#0000FF')
MyGraph.add_node('D', npos=(50, 25), ccn='#00FF00')
MyGraph.add_node('E', npos=(54, 36), ccn='#0000FF')
MyGraph.add_node('F', npos=(58, 50), ccn='#0000FF')
MyGraph.add_node('G', npos=(50, 50), ccn='#00FF00')
MyGraph.add_node('H', npos=(50, 85), ccn='#00FF00')
MyGraph.add_node('I', npos=(50, 0), ccn='#FF7F3E')
MyGraph.add_node('J', npos=(50, -28), ccn='#FF7F3E')
MyGraph.add_node('K', npos=(50, -62), ccn='#FF7F3E')
MyGraph.add_node('L', npos=(43, 50), ccn='#00FF00')
MyGraph.add_node('M', npos=(37, 50), ccn='#FF0000')
MyGraph.add_node('N', npos=(25, 50), ccn='#FF0000')
MyGraph.add_node('O', npos=(15, 50), ccn='#FF0000')
MyGraph.add_node('P', npos=(56, 105), ccn='#00FFFF')
MyGraph.add_node('Q', npos=(38, -27), ccn='#00FFFF')
MyGraph.add_node('R', npos=(42, -85), ccn='#00FFFF')

#Connection for the greenline
MyGraph.add_edge('A', 'B', cce='#0000FF')
MyGraph.add_edge('B', 'C', cce='#0000FF')
MyGraph.add_edge('C', 'D', cce='#0000FF')
MyGraph.add_edge('D', 'E', cce='#0000FF')
MyGraph.add_edge('E', 'F', cce='#0000FF')
MyGraph.add_edge('D', 'G', cce='#FF7F3E')
MyGraph.add_edge('G', 'H', cce='#FF7F3E')
MyGraph.add_edge('D', 'I', cce='#FF7F3E')
MyGraph.add_edge('I', 'J', cce='#FF7F3E')
MyGraph.add_edge('J', 'K', cce='#FF7F3E')
MyGraph.add_edge('G', 'F', cce='#FF0000')
MyGraph.add_edge('G', 'L', cce='#FF0000')
MyGraph.add_edge('L', 'M', cce='#FF0000')
MyGraph.add_edge('M', 'N', cce='#FF0000')
MyGraph.add_edge('N', 'O', cce='#FF0000')
MyGraph.add_edge('H', 'L', cce='#00FFFF')
MyGraph.add_edge('L', 'B', cce='#00FFFF')
MyGraph.add_edge('H', 'P', cce='#00FFFF')
MyGraph.add_edge('B', 'Q', cce='#00FFFF')
MyGraph.add_edge('Q', 'R', cce='#00FFFF')


#Extract attributes from graph to dictionary
pos = nx.get_node_attributes(MyGraph,'npos')
nodecolour = nx.get_node_attributes(MyGraph, 'ccn')
edgecolour = nx.get_edge_attributes(MyGraph, 'cce')

#Change the size of the figure
plt.figure(figsize=(15, 11))

#Place dictionary in lists
NodeList = list(nodecolour.values())
EdgeList= list(edgecolour.values()) 

#Sum
numbers = [0.6, 0.3, 0.1, 0.16, 0.32,1.8,2.5,0.5,1.1,2.35,0.5,0.33,0.22,0.26,0.44,0.31,0.76,0.63,0.76,0.44] 
total = 0
for num in numbers:
    total += num

#Average & Standard Deviation distance between station:
Piccadillyline = np.array([0.6,0.3,0.1,0.16,0.32])
Average_Piccadillyline = np.average(Piccadillyline)
SD_Piccadillyline = np.std(Piccadillyline)
Northernline = np.array([0.5,0.33,0.22,0.26,0.44])
Average_Nothernline = np.average(Northernline)
SD_Nothernline = np.std(Northernline)
Centralline = np.array([1.8,2.5,0.5,1.1,2.35])
Average_Centralline = np.average(Centralline)
SD_Centralline = np.std(Centralline)
Victorialine=np.array([0.31,0.76,0.63,0.76,0.44])
Average_Victorialine = np.average(Victorialine)
SD_Victorialine = np.std(Victorialine)

#Display the station name
plt.text(26, -1, s='Hyde Park Corner', rotation=0)
plt.text(33, 25, s='Green Park', rotation=0)
plt.text(40, -3, s='Piccadilly Circus', rotation=45)
plt.text(50.3, 8, s='Leicester Square', rotation=-25)
plt.text(54.5, 20, s='Convent Garden', rotation=-20)
plt.text(59, 49, s='Holborn', rotation=0)
plt.text(50.5, 54, s='Tottenham Court Road', rotation=45)
plt.text(44, 84, s='Warren Street', rotation=0)
plt.text(44, -1, s='Charing Cross', rotation=0)
plt.text(44.5, -28.5, s='Embankment', rotation=0)
plt.text(46, -62.5, s='Waterloo', rotation=0)
plt.text(38 , 53, s='Oxford Circus', rotation=-40)
plt.text(34 , 55, s='Bond Street', rotation=0)
plt.text(20 , 55, s='Notting Hill Gate', rotation=0)
plt.text(13 , 56, s='Sheppard Bush', rotation=0)
plt.text(56 , 109, s='Euston', rotation=0)
plt.text(34.5, -27.5, s='Victoria', rotation=0)
plt.text(38, -85.5, s='Vauxhall', rotation=0)

#Display the Miles/Kilometer
plt.text(32, 13, s='0.6 Miles')
plt.text(40, 20, s='0.3 Miles')
plt.text(46, 20, s='0.1 Miles')
plt.text(52, 20, s='0.16 Miles', rotation=-20)
plt.text(56, 33, s='0.32 Miles', rotation=-20)
plt.text(18, 44, s='1.8 Miles')
plt.text(30, 44, s='2.5 Miles')
plt.text(38, 43.5, s='0.5 Miles')
plt.text(45, 44, s='1.1 Miles')
plt.text(51.5, 44.5, s='2.35 Miles')
plt.text(46.5, 63, s='0.5 Miles')
plt.text(46, 37, s='0.33 Miles')
plt.text(46, 10, s='0.22 Miles')
plt.text(46, -14, s='0.26 Miles')
plt.text(46, -47, s='0.44 Miles')
plt.text(51.5, 85, s='0.31 Miles', rotation = 30)
plt.text(44.5, 63, s='0.76 Miles', rotation= 40)
plt.text(39.5, 28, s='0.63 Miles', rotation= 40)
plt.text(38.5, -10, s='0.76 Miles', rotation = 90)
plt.text(39.5,-60, s='0.44 Miles', rotation= 111)

#Display explanation box
plt.text(53, -70, "Key", fontsize=12, fontweight='bold')
plt.plot(6.5, -1.5, color='blue', label='Piccadilly Line')
plt.plot(6.5,-1.5, color='orange', label='Northern Line')
plt.plot(6.5,-1.5, color='red', label='Central Line')
plt.plot(6.5,-1.5, color='cyan', label='Victoria Line')
plt.plot(38,25, marker ='o', color='none', markerfacecolor ="lightgreen",label='Interchange Stations')
plt.text(
    4.5, -100,
    f'''Sum: {total:.2f} miles
    Piccadillyline Average: {Average_Piccadillyline:.2f} miles
    Piccadillyline Standard: {SD_Piccadillyline:.2f} miles
    Nothernline Average: {Average_Nothernline} miles
    Nothernline Standard: {SD_Nothernline:.2f} miles
    Centralline Average: {Average_Centralline} miles
    Centralline Standard: {SD_Centralline:.2f} miles
    Victorialine Average: {Average_Victorialine} miles
    Victorialine Standard: {SD_Victorialine:.2f} miles''',
    bbox=dict(facecolor='white', alpha=0.5)
)
plt.legend(loc='lower right')

#Draw Graph
nx.draw_networkx(MyGraph, pos, node_color=NodeList)
nx.draw_networkx_edges(MyGraph, pos, edge_color=EdgeList)

#Show graph
plt.show()
